# %%
import argparse

from focused_crawler import Focused_Crawler_Reinforcement_Learning
from ground_truth import Ground_Truth
from link_evaluation import CNN
# Out:
# D:\Anaconda3\lib\site-packages\gensim\utils.py:1197: UserWarning: detected Windows; aliasing chunkize to chunkize_serial
#   warnings.warn("detected Windows; aliasing chunkize to chunkize_serial")
# Using TensorFlow backend.

# %%
parser = argparse.ArgumentParser(description='Focused Crawler')
# input
parser.add_argument('--seeds', default=['https://cs.illinois.edu/'], help='the start \
                    domains for crawling')
parser.add_argument('--limit_pages', default=20, help='the maximum \
                    websites to visit')
parser.add_argument('--topics', default='artificial intelligence', help='target \
                    topics')
# Q learning parameters
parser.add_argument('--epsilon', default=0.1, help='epsilon-greedy policy')
parser.add_argument('--alpha', default=0.01, help='learning rate')
parser.add_argument('--gamma', default=0.9, help='discount rate')
# change of relevance
parser.add_argument('--beta', default=0.5, help='relevance change of target topics')
parser.add_argument('--sigma1', default=0.1, help='first difference parameter')
parser.add_argument('--sigma2', default=0.3, help='second difference parameter')
parser.add_argument('--level', default=3, help='recursively update child for some \
                    levels, may update a page twice')
# relevant threshold
parser.add_argument('--relevant', default=0.7, help='the page whose relevance \
                    higher than this value is regarded as relevant page')
# reward
parser.add_argument('--reward_true', default=30, help='the reward when page \
                    is relevant')
parser.add_argument('--reward_false', default=-1, help='the reward when page \
                    is not relevant')
# mode
parser.add_argument('--synchronization', default=0, help='the way to \
                    update the value in queue. mode 0, 1, 2 represent: \
                    synchronous, asynchronous, moderated')

args = parser.parse_args([])

# %%
Focused_Crawler = Focused_Crawler_Reinforcement_Learning(args.topics)

# key_word = 'artificial intelligence'
# ground_truth = Ground_Truth(key_word, 1000)
# Focused_Crawler.test(ground_truth)
# Out:
# Model loaded.
# WARNING:tensorflow:From D:\Anaconda3\lib\site-packages\tensorflow\python\framework\op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# WARNING:tensorflow:From D:\Anaconda3\lib\site-packages\tensorflow\python\ops\math_ops.py:3066: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.

# %%
Focused_Crawler.train(args)
# Out:
# No. -1
# link: https://cs.illinois.edu/
# parent_link: NULL
# outlinks: 251
# reward: NULL
# B: 251
# --------------------------------------------------------------------------------
# No. 0
# link: http://cs.engr.illinois.edu/admissions/financial-aid#overview
# parent_link: https://cs.illinois.edu/
# outlinks: 252
# reward: -1
# B: 502
# --------------------------------------------------------------------------------
# No. 1
# link: http://cs.engr.illinois.edu/
# parent_link: http://cs.engr.illinois.edu/admissions/financial-aid#overview
# outlinks: 251
# reward: -1
# B: 752
# --------------------------------------------------------------------------------
# No. 2
# link: http://cs.engr.illinois.edu/about-us
# parent_link: http://cs.engr.illinois.edu/
# outlinks: 250
# reward: -1
# B: 1001
# --------------------------------------------------------------------------------
# No. 3
# link: http://cs.engr.illinois.edu/about-us/accreditation
# parent_link: http://cs.engr.illinois.edu/about-us
# outlinks: 249
# reward: -1
# B: 1249
# --------------------------------------------------------------------------------
# No. 4
# link: http://cs.engr.illinois.edu/about-us/awards
# parent_link: http://cs.engr.illinois.edu/about-us/accreditation
# outlinks: 248
# reward: -1
# B: 1496
# --------------------------------------------------------------------------------
# No. 5
# link: http://cs.engr.illinois.edu/about-us/awards/alumni-awards
# parent_link: http://cs.engr.illinois.edu/about-us/awards
# outlinks: 247
# reward: -1
# B: 1742
# --------------------------------------------------------------------------------
# No. 6
# link: http://cs.engr.illinois.edu/about-us/awards/alumni-awards/alumni-awards-past-recipients
# parent_link: http://cs.engr.illinois.edu/about-us/awards/alumni-awards
# outlinks: 246
# reward: -1
# B: 1987
# --------------------------------------------------------------------------------
# No. 7
# link: http://cs.engr.illinois.edu/about-us/awards/alumni-awards/national-international-awards
# parent_link: http://cs.engr.illinois.edu/about-us/awards/alumni-awards/alumni-awards-past-recipients
# outlinks: 245
# reward: -1
# B: 2231
# --------------------------------------------------------------------------------
# No. 8
# link: http://cs.engr.illinois.edu/about-us/awards/alumni-awards/university-illinois-awards
# parent_link: http://cs.engr.illinois.edu/about-us/awards/alumni-awards/national-international-awards
# outlinks: 244
# reward: -1
# B: 2474
# --------------------------------------------------------------------------------
# No. 9
# link: http://cs.engr.illinois.edu/about-us/awards/faculty-awards
# parent_link: http://cs.engr.illinois.edu/about-us/awards/alumni-awards/university-illinois-awards
# outlinks: 243
# reward: -1
# B: 2716
# --------------------------------------------------------------------------------
# No. 10
# link: http://cs.illinois.edu/about-us/awards/alumni-awards
# parent_link: https://cs.illinois.edu/
# outlinks: 229
# reward: -1
# B: 2944
# --------------------------------------------------------------------------------
# No. 11
# link: http://cs.illinois.edu/
# parent_link: http://cs.illinois.edu/about-us/awards/alumni-awards
# outlinks: 240
# reward: -1
# B: 3183
# --------------------------------------------------------------------------------
# No. 12
# link: http://cs.illinois.edu/academics/degree-program-options
# parent_link: https://cs.illinois.edu/
# outlinks: 224
# reward: -1
# B: 3406
# --------------------------------------------------------------------------------
# No. 13
# link: http://cs.illinois.edu/about-us
# parent_link: http://cs.illinois.edu/academics/degree-program-options
# outlinks: 225
# reward: -1
# B: 3630
# --------------------------------------------------------------------------------
# No. 14
# link: http://cs.illinois.edu/academics/explore-courses
# parent_link: https://cs.illinois.edu/
# outlinks: 224
# reward: -1
# B: 3853
# --------------------------------------------------------------------------------
# No. 15
# link: http://cs.illinois.edu/about-us/accreditation
# parent_link: http://cs.illinois.edu/academics/explore-courses
# outlinks: 224
# reward: -1
# B: 4076
# --------------------------------------------------------------------------------
# No. 16
# link: http://cs.illinois.edu/academics/graduate/non-degree-options
# parent_link: https://cs.illinois.edu/
# outlinks: 225
# reward: -1
# B: 4300
# --------------------------------------------------------------------------------
# No. 17
# link: http://cs.illinois.edu/about-us/awards
# parent_link: http://cs.illinois.edu/academics/graduate/non-degree-options
# outlinks: 219
# reward: -1
# B: 4518
# --------------------------------------------------------------------------------
# No. 18
# link: http://cs.illinois.edu/admissions/financial-aid
# parent_link: https://cs.illinois.edu/
# outlinks: 229
# reward: -1
# B: 4746
# --------------------------------------------------------------------------------
# No. 19
# link: https://www.instagram.com/illinoiscs/
# parent_link: http://cs.illinois.edu/admissions/financial-aid
# outlinks: NULL
# reward: -1
# B: 4745
# --------------------------------------------------------------------------------
# Final w: [ 0.01        0.01        0.01       -0.1691576   0.01       -0.1691576
#   0.01        0.01        0.01        0.01       -0.04898939  0.01
#   0.01       -0.11016821  0.01       -0.1691576   0.01        0.01
#   0.01        0.01        0.01        0.01        0.01        0.01
#  -0.1691576  -0.1691576   0.01        0.01        0.01        0.01
#   0.01        0.01        0.01       -0.1691576   0.01       -0.1691576
#   0.01        0.01        0.01        0.01      ]

# %%
display('DG:', Focused_Crawler.DG.nodes.data())
# Out:
# 'DG:'
# NodeDataView({'https://cs.illinois.edu/': {'relevant': False, 'relevance': 0.65677136, 'my': 0.6567713618278503, 'max': 0.65677136}, 'http://cs.engr.illinois.edu/admissions/financial-aid#overview': {'relevant': False, 'relevance': 0.65677136, 'my': 0.6609881222248077, 'max': 0.6652048826217651}, 'http://cs.engr.illinois.edu/': {'relevant': False, 'relevance': 0.65677136, 'my': 0.658879742026329, 'max': 0.6609881222248077}, 'http://cs.engr.illinois.edu/about-us': {'relevant': False, 'relevance': 0.65677136, 'my': 0.6578255519270897, 'max': 0.658879742026329}, 'http://cs.engr.illinois.edu/about-us/accreditation': {'relevant': False, 'relevance': 0.65677136, 'my': 0.65729845687747, 'max': 0.6578255519270897}, 'http://cs.engr.illinois.edu/about-us/awards': {'relevant': False, 'relevance': 0.65677136, 'my': 0.6567713618278503, 'max': 0.6567713618278503}, 'http://cs.engr.illinois.edu/about-us/awards/alumni-awards': {'relevant': False, 'relevance': 0.65677136, 'my': 0.6567713618278503, 'max': 0.6567713618278503}, 'http://cs.engr.illinois.edu/about-us/awards/alumni-awards/alumni-awards-past-recipients': {'relevant': False, 'relevance': 0.65677136, 'my': 0.6567713618278503, 'max': 0.6567713618278503}, 'http://cs.engr.illinois.edu/about-us/awards/alumni-awards/national-international-awards': {'relevant': False, 'relevance': 0.65677136, 'my': 0.6567713618278503, 'max': 0.6567713618278503}, 'http://cs.engr.illinois.edu/about-us/awards/alumni-awards/university-illinois-awards': {'relevant': False, 'relevance': 0.65677136, 'my': 0.6567713618278503, 'max': 0.6567713618278503}, 'http://cs.engr.illinois.edu/about-us/awards/faculty-awards': {'relevant': False, 'relevance': 0.65677136, 'my': 0.6567713618278503, 'max': 0.6567713618278503}, 'http://cs.illinois.edu/about-us/awards/alumni-awards': {'relevant': False, 'relevance': 0.65703565, 'my': 0.6611202657222748, 'max': 0.6652048826217651}, 'http://cs.illinois.edu/': {'relevant': False, 'relevance': 0.65677136, 'my': 0.6609881222248077, 'max': 0.6652048826217651}, 'http://cs.illinois.edu/academics/degree-program-options': {'relevant': False, 'relevance': 0.6570696, 'my': 0.6611372530460358, 'max': 0.6652048826217651}, 'http://cs.illinois.edu/about-us': {'relevant': False, 'relevance': 0.6652049, 'my': 0.6652048826217651, 'max': 0.6652048826217651}, 'http://cs.illinois.edu/academics/explore-courses': {'relevant': False, 'relevance': 0.6567522, 'my': 0.6568535254309609, 'max': 0.6569548221250443}, 'http://cs.illinois.edu/about-us/accreditation': {'relevant': False, 'relevance': 0.6567522, 'my': 0.6568535254309609, 'max': 0.6569548221250443}, 'http://cs.illinois.edu/academics/graduate/non-degree-options': {'relevant': False, 'relevance': 0.6569548, 'my': 0.6569548235247566, 'max': 0.6569548221250443}, 'http://cs.illinois.edu/about-us/awards': {'relevant': False, 'relevance': 0.6568269, 'my': 0.6568908684407688, 'max': 0.6569548235247566}, 'http://cs.illinois.edu/admissions/financial-aid': {'relevant': False, 'relevance': 0.6568497, 'my': 0.6568472348153591, 'max': 0.656844787299633}, 'https://www.instagram.com/illinoiscs/': {'relevant': False, 'relevance': 0.6641221, 'my': 0.6604846697300673, 'max': 0.6568472348153591}})
